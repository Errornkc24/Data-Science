# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib .pyplot as plt

# %%
df=pd.read_csv("Datasets-main/CardioGoodFitness-1.csv")
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# ## Univeriate

# %%
sns.countplot(x="Fitness",data=df)
# Out:
# <AxesSubplot:xlabel='Fitness', ylabel='count'>

# %%
sns.countplot(x="Gender",data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="MaritalStatus",data=df)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
sns.boxplot(x="Age",data=df)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
sns.boxplot(x="Education",data=df)
# Out:
# <AxesSubplot:xlabel='Education'>

# %%
plt.hist(x="Age",data=df)
# Out:
# (array([17., 37., 44., 22., 18., 17., 13.,  3.,  4.,  5.]),
#  array([18. , 21.2, 24.4, 27.6, 30.8, 34. , 37.2, 40.4, 43.6, 46.8, 50. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.catplot(x='Fitness', y='Age',data=df)

# %%
sns.catplot(x='Usage', y='Miles',data=df)

# %%
sns.catplot(x='Fitness',y='Age',hue='Gender', data=df)
